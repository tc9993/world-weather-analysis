# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combos
lats = np.random.uniform(-90 , 90 , size = 2000)
lngs = np.random.uniform(-180 , 180 , size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then add to the cities list
    if city not in cities:
        cities.append(city)
        
# Print length of city count to confirm enough
len(cities)
# Out:
# 755

# %%
city_data = []
print("starting to log city_data")
print("-------------------------")

# Create Counters
record_count = 1
set_count = 1

url = "https://api.openweathermap.org/data/2.5/weather?&units=imperial&appid=" + weather_api_key
# loop through the cities list
for i, city in enumerate(cities):
    
    # Group the cities in sets of 50 to log the process as we find the weather data
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        
    # Create endpoint url with each city
    city_url = url + "&q=" + city.replace(" " , "+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# starting to log city_data
# -------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | nantucket
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | yar-sale
# Processing Record 14 of Set 1 | hasaki
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | ostrovnoy
# Processing Record 18 of Set 1 | yulara
# Processing Record 19 of Set 1 | hamilton
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | san patricio
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | almeirim
# Processing Record 26 of Set 1 | pangnirtung
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | balykshi
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | orel-izumrud
# Processing Record 33 of Set 1 | fortuna
# Processing Record 34 of Set 1 | talnakh
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | sragen
# Processing Record 37 of Set 1 | bathsheba
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | college
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | coquimbo
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | khor
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | hambantota
# Processing Record 1 of Set 2 | pitimbu
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | bardsir
# Processing Record 5 of Set 2 | lasa
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | bjornevatn
# Processing Record 8 of Set 2 | airai
# Processing Record 9 of Set 2 | bow island
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | lumsden
# Processing Record 12 of Set 2 | chicama
# Processing Record 13 of Set 2 | mosquera
# Processing Record 14 of Set 2 | kloulklubed
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | severo-kurilsk
# Processing Record 18 of Set 2 | jaguarao
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | cidreira
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 2 | trairi
# Processing Record 25 of Set 2 | hithadhoo
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | westport
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | freeport
# Processing Record 30 of Set 2 | sechura
# Processing Record 31 of Set 2 | asau
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | pauini
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | pisco
# Processing Record 37 of Set 2 | norsup
# Processing Record 38 of Set 2 | riyadh
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | lorengau
# Processing Record 41 of Set 2 | saurimo
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | colesberg
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | sol-iletsk
# Processing Record 46 of Set 2 | guerrero negro
# Processing Record 47 of Set 2 | mount gambier
# Processing Record 48 of Set 2 | mikkeli
# Processing Record 49 of Set 2 | banjar
# Processing Record 50 of Set 2 | hay river
# Processing Record 1 of Set 3 | odweyne
# Processing Record 2 of Set 3 | eureka
# Processing Record 3 of Set 3 | olinda
# Processing Record 4 of Set 3 | miguel alves
# Processing Record 5 of Set 3 | mahon
# Processing Record 6 of Set 3 | broome
# Processing Record 7 of Set 3 | san policarpo
# Processing Record 8 of Set 3 | norman wells
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | rio bueno
# Processing Record 11 of Set 3 | morant bay
# Processing Record 12 of Set 3 | tadine
# Processing Record 13 of Set 3 | nyrob
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | wanning
# Processing Record 17 of Set 3 | neepawa
# Processing Record 18 of Set 3 | okha
# Processing Record 19 of Set 3 | daru
# Processing Record 20 of Set 3 | ratanpur
# Processing Record 21 of Set 3 | aldine
# Processing Record 22 of Set 3 | coihaique
# Processing Record 23 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | porbandar
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | rawson
# Processing Record 28 of Set 3 | sovetskiy
# Processing Record 29 of Set 3 | sena madureira
# Processing Record 30 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | patos
# Processing Record 33 of Set 3 | inirida
# Processing Record 34 of Set 3 | kalmunai
# Processing Record 35 of Set 3 | belaya gora
# Processing Record 36 of Set 3 | umba
# Processing Record 37 of Set 3 | suhbaatar
# Processing Record 38 of Set 3 | sabla
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | san juan bautista
# Processing Record 41 of Set 3 | serula
# Processing Record 42 of Set 3 | kjopsvik
# Processing Record 43 of Set 3 | nouadhibou
# Processing Record 44 of Set 3 | bartica
# Processing Record 45 of Set 3 | garissa
# Processing Record 46 of Set 3 | lodja
# Processing Record 47 of Set 3 | port macquarie
# Processing Record 48 of Set 3 | lompoc
# Processing Record 49 of Set 3 | luena
# Processing Record 50 of Set 3 | provideniya
# Processing Record 1 of Set 4 | kargasok
# Processing Record 2 of Set 4 | zlatoustovsk
# City not found. Skipping...
# Processing Record 3 of Set 4 | karlshamn
# Processing Record 4 of Set 4 | pychas
# Processing Record 5 of Set 4 | upernavik
# Processing Record 6 of Set 4 | aklavik
# Processing Record 7 of Set 4 | mikumi
# Processing Record 8 of Set 4 | cockburn town
# Processing Record 9 of Set 4 | ipojuca
# Processing Record 10 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 4 | coro
# Processing Record 12 of Set 4 | provost
# Processing Record 13 of Set 4 | salinas
# Processing Record 14 of Set 4 | northam
# Processing Record 15 of Set 4 | san borja
# Processing Record 16 of Set 4 | okandja
# City not found. Skipping...
# Processing Record 17 of Set 4 | chokurdakh
# Processing Record 18 of Set 4 | husavik
# Processing Record 19 of Set 4 | mujiayingzi
# Processing Record 20 of Set 4 | byron bay
# Processing Record 21 of Set 4 | horodnya
# Processing Record 22 of Set 4 | vanavara
# Processing Record 23 of Set 4 | lata
# Processing Record 24 of Set 4 | payo
# Processing Record 25 of Set 4 | saint-joseph
# Processing Record 26 of Set 4 | sheridan
# Processing Record 27 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | clyde river
# Processing Record 30 of Set 4 | meulaboh
# Processing Record 31 of Set 4 | xining
# Processing Record 32 of Set 4 | uchiza
# Processing Record 33 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 4 | tilichiki
# Processing Record 35 of Set 4 | namatanai
# Processing Record 36 of Set 4 | glenwood springs
# Processing Record 37 of Set 4 | rolla
# Processing Record 38 of Set 4 | linqiong
# Processing Record 39 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 4 | kitgum
# Processing Record 41 of Set 4 | nishihara
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 4 | nizhniy baskunchak
# Processing Record 44 of Set 4 | katsuura
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | revda
# Processing Record 47 of Set 4 | caconda
# Processing Record 48 of Set 4 | qaanaaq
# Processing Record 49 of Set 4 | tarakan
# Processing Record 50 of Set 4 | atbasar
# Processing Record 1 of Set 5 | broken hill
# Processing Record 2 of Set 5 | beringovskiy
# Processing Record 3 of Set 5 | umm kaddadah
# Processing Record 4 of Set 5 | san rafael del sur
# Processing Record 5 of Set 5 | palmer
# Processing Record 6 of Set 5 | port alfred
# Processing Record 7 of Set 5 | tuktoyaktuk
# Processing Record 8 of Set 5 | ponta do sol
# Processing Record 9 of Set 5 | kurtamysh
# Processing Record 10 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 5 | constitucion
# Processing Record 12 of Set 5 | karakulino
# Processing Record 13 of Set 5 | dahuk
# Processing Record 14 of Set 5 | saalfeld
# Processing Record 15 of Set 5 | margate
# Processing Record 16 of Set 5 | arkhangelsk
# Processing Record 17 of Set 5 | sibi
# Processing Record 18 of Set 5 | luderitz
# Processing Record 19 of Set 5 | nadym
# Processing Record 20 of Set 5 | kobojango
# City not found. Skipping...
# Processing Record 21 of Set 5 | kyrksaeterora
# Processing Record 22 of Set 5 | corner brook
# Processing Record 23 of Set 5 | sorong
# Processing Record 24 of Set 5 | madaoua
# Processing Record 25 of Set 5 | magadan
# Processing Record 26 of Set 5 | port lincoln
# Processing Record 27 of Set 5 | atar
# Processing Record 28 of Set 5 | kudahuvadhoo
# Processing Record 29 of Set 5 | turtkul
# City not found. Skipping...
# Processing Record 30 of Set 5 | noumea
# Processing Record 31 of Set 5 | bayan
# Processing Record 32 of Set 5 | machali
# Processing Record 33 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 5 | almaty
# Processing Record 35 of Set 5 | torbay
# Processing Record 36 of Set 5 | saint-philippe
# Processing Record 37 of Set 5 | portland
# Processing Record 38 of Set 5 | tura
# Processing Record 39 of Set 5 | naze
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 42 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 5 | hearst
# Processing Record 44 of Set 5 | codrington
# Processing Record 45 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 5 | vila velha
# Processing Record 47 of Set 5 | candolim
# Processing Record 48 of Set 5 | kysyl-syr
# Processing Record 49 of Set 5 | marsh harbour
# Processing Record 50 of Set 5 | wroclaw
# Processing Record 1 of Set 6 | alta floresta
# Processing Record 2 of Set 6 | san cristobal
# Processing Record 3 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 6 | vardo
# Processing Record 5 of Set 6 | ust-kuyga
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | jacareacanga
# Processing Record 8 of Set 6 | selikhino
# Processing Record 9 of Set 6 | sobolevo
# Processing Record 10 of Set 6 | laguna
# Processing Record 11 of Set 6 | halifax
# Processing Record 12 of Set 6 | parabel
# Processing Record 13 of Set 6 | beni
# Processing Record 14 of Set 6 | makungu
# Processing Record 15 of Set 6 | ancud
# Processing Record 16 of Set 6 | kang
# Processing Record 17 of Set 6 | lagoa
# Processing Record 18 of Set 6 | camacha
# Processing Record 19 of Set 6 | necochea
# Processing Record 20 of Set 6 | rochegda
# Processing Record 21 of Set 6 | gat
# Processing Record 22 of Set 6 | yuncheng
# Processing Record 23 of Set 6 | mmathubudukwane
# Processing Record 24 of Set 6 | ola
# Processing Record 25 of Set 6 | los llanos de aridane
# Processing Record 26 of Set 6 | xadani
# City not found. Skipping...
# Processing Record 27 of Set 6 | acapulco
# Processing Record 28 of Set 6 | sohodol
# Processing Record 29 of Set 6 | ketchikan
# Processing Record 30 of Set 6 | roebourne
# Processing Record 31 of Set 6 | den helder
# Processing Record 32 of Set 6 | chapais
# Processing Record 33 of Set 6 | cankuzo
# Processing Record 34 of Set 6 | isangel
# Processing Record 35 of Set 6 | iskateley
# Processing Record 36 of Set 6 | vila franca do campo
# Processing Record 37 of Set 6 | geraldton
# Processing Record 38 of Set 6 | te anau
# Processing Record 39 of Set 6 | labrea
# Processing Record 40 of Set 6 | woodburn
# Processing Record 41 of Set 6 | gravdal
# Processing Record 42 of Set 6 | fort nelson
# Processing Record 43 of Set 6 | qaqortoq
# Processing Record 44 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 45 of Set 6 | puerto ayacucho
# Processing Record 46 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 47 of Set 6 | santiago del estero
# Processing Record 48 of Set 6 | wajima
# Processing Record 49 of Set 6 | havoysund
# Processing Record 50 of Set 6 | nago
# Processing Record 1 of Set 7 | taoudenni
# Processing Record 2 of Set 7 | leningradskiy
# Processing Record 3 of Set 7 | savannah bight
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | tasiilaq
# Processing Record 6 of Set 7 | tiksi
# Processing Record 7 of Set 7 | nanortalik
# Processing Record 8 of Set 7 | bazarnyye mataki
# Processing Record 9 of Set 7 | la ronge
# Processing Record 10 of Set 7 | oum hadjer
# Processing Record 11 of Set 7 | narsaq
# Processing Record 12 of Set 7 | kot radha kishan
# Processing Record 13 of Set 7 | saint anthony
# Processing Record 14 of Set 7 | saleilua
# City not found. Skipping...
# Processing Record 15 of Set 7 | kutum
# Processing Record 16 of Set 7 | syracuse
# Processing Record 17 of Set 7 | santa rosa
# Processing Record 18 of Set 7 | burica
# City not found. Skipping...
# Processing Record 19 of Set 7 | vao
# Processing Record 20 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 7 | rondonopolis
# Processing Record 22 of Set 7 | tigbao
# Processing Record 23 of Set 7 | charters towers
# Processing Record 24 of Set 7 | innisfail
# Processing Record 25 of Set 7 | buraydah
# Processing Record 26 of Set 7 | ciudad bolivar
# Processing Record 27 of Set 7 | storforshei
# Processing Record 28 of Set 7 | aranos
# Processing Record 29 of Set 7 | carauari
# Processing Record 30 of Set 7 | chuguyevka
# Processing Record 31 of Set 7 | barddhaman
# Processing Record 32 of Set 7 | matagami
# Processing Record 33 of Set 7 | nemuro
# Processing Record 34 of Set 7 | gobabis
# Processing Record 35 of Set 7 | zvishavane
# Processing Record 36 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 7 | kjollefjord
# Processing Record 38 of Set 7 | vostok
# Processing Record 39 of Set 7 | obo
# Processing Record 40 of Set 7 | giyani
# Processing Record 41 of Set 7 | morondava
# Processing Record 42 of Set 7 | saint-augustin
# Processing Record 43 of Set 7 | irondequoit
# Processing Record 44 of Set 7 | takaka
# Processing Record 45 of Set 7 | hofn
# Processing Record 46 of Set 7 | egvekinot
# Processing Record 47 of Set 7 | sisimiut
# Processing Record 48 of Set 7 | omboue
# Processing Record 49 of Set 7 | santa maria
# Processing Record 50 of Set 7 | lexington
# Processing Record 1 of Set 8 | roma
# Processing Record 2 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 3 of Set 8 | garbolovo
# Processing Record 4 of Set 8 | olafsvik
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | sao felix do xingu
# Processing Record 7 of Set 8 | tautira
# Processing Record 8 of Set 8 | arman
# Processing Record 9 of Set 8 | moroni
# Processing Record 10 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 8 | ulladulla
# Processing Record 12 of Set 8 | kabare
# Processing Record 13 of Set 8 | felanitx
# Processing Record 14 of Set 8 | nizza monferrato
# Processing Record 15 of Set 8 | khani
# Processing Record 16 of Set 8 | nuevo laredo
# Processing Record 17 of Set 8 | komsomolets
# Processing Record 18 of Set 8 | muzhi
# Processing Record 19 of Set 8 | dianopolis
# City not found. Skipping...
# Processing Record 20 of Set 8 | puerto escondido
# Processing Record 21 of Set 8 | alofi
# Processing Record 22 of Set 8 | cayenne
# Processing Record 23 of Set 8 | bichena
# Processing Record 24 of Set 8 | chapadinha
# Processing Record 25 of Set 8 | klaksvik
# Processing Record 26 of Set 8 | ouegoa
# Processing Record 27 of Set 8 | bamnet narong
# Processing Record 28 of Set 8 | ambilobe
# Processing Record 29 of Set 8 | inhambane
# Processing Record 30 of Set 8 | padang
# Processing Record 31 of Set 8 | keti bandar
# Processing Record 32 of Set 8 | haines junction
# Processing Record 33 of Set 8 | sakakah
# Processing Record 34 of Set 8 | pinheiro machado
# Processing Record 35 of Set 8 | santa catalina
# Processing Record 36 of Set 8 | deputatskiy
# Processing Record 37 of Set 8 | pochutla
# Processing Record 38 of Set 8 | muriti
# Processing Record 39 of Set 8 | thompson
# Processing Record 40 of Set 8 | adrar
# Processing Record 41 of Set 8 | pevek
# Processing Record 42 of Set 8 | ciudad valles
# Processing Record 43 of Set 8 | azalea park
# Processing Record 44 of Set 8 | smithers
# Processing Record 45 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 8 | korla
# Processing Record 47 of Set 8 | alugan
# Processing Record 48 of Set 8 | bachaquero
# Processing Record 49 of Set 8 | bara
# Processing Record 50 of Set 8 | luanda
# Processing Record 1 of Set 9 | namibe
# Processing Record 2 of Set 9 | along
# Processing Record 3 of Set 9 | tamworth
# Processing Record 4 of Set 9 | pizarro
# Processing Record 5 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 9 | paamiut
# Processing Record 7 of Set 9 | brownsville
# Processing Record 8 of Set 9 | alikalia
# Processing Record 9 of Set 9 | vrangel
# Processing Record 10 of Set 9 | port-gentil
# Processing Record 11 of Set 9 | fiche
# Processing Record 12 of Set 9 | sao raimundo das mangabeiras
# Processing Record 13 of Set 9 | barra do garcas
# Processing Record 14 of Set 9 | berezovyy
# Processing Record 15 of Set 9 | santa maria la alta
# Processing Record 16 of Set 9 | ngunguru
# Processing Record 17 of Set 9 | coahuayana
# Processing Record 18 of Set 9 | saint simons
# Processing Record 19 of Set 9 | zutphen
# Processing Record 20 of Set 9 | vestmanna
# Processing Record 21 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 22 of Set 9 | colac
# Processing Record 23 of Set 9 | yambio
# Processing Record 24 of Set 9 | poum
# Processing Record 25 of Set 9 | dingle
# Processing Record 26 of Set 9 | moron
# Processing Record 27 of Set 9 | turukhansk
# Processing Record 28 of Set 9 | xiongyue
# Processing Record 29 of Set 9 | marawi
# Processing Record 30 of Set 9 | beloha
# Processing Record 31 of Set 9 | mlada vozice
# Processing Record 32 of Set 9 | saldanha
# Processing Record 33 of Set 9 | salalah
# Processing Record 34 of Set 9 | takoradi
# Processing Record 35 of Set 9 | lagos
# Processing Record 36 of Set 9 | solnechnyy
# Processing Record 37 of Set 9 | marfino
# Processing Record 38 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 9 | devonport
# Processing Record 40 of Set 9 | van
# Processing Record 41 of Set 9 | barao de melgaco
# Processing Record 42 of Set 9 | tefe
# Processing Record 43 of Set 9 | coaticook
# Processing Record 44 of Set 9 | bulawayo
# Processing Record 45 of Set 9 | pacifica
# Processing Record 46 of Set 9 | seoul
# Processing Record 47 of Set 9 | pontes e lacerda
# Processing Record 48 of Set 9 | bengkulu
# Processing Record 49 of Set 9 | fairbanks
# Processing Record 50 of Set 9 | vanimo
# Processing Record 1 of Set 10 | zaraza
# Processing Record 2 of Set 10 | champerico
# Processing Record 3 of Set 10 | vila
# Processing Record 4 of Set 10 | pacific grove
# Processing Record 5 of Set 10 | liverpool
# Processing Record 6 of Set 10 | dolores
# Processing Record 7 of Set 10 | banda aceh
# Processing Record 8 of Set 10 | ramon
# Processing Record 9 of Set 10 | aswan
# Processing Record 10 of Set 10 | whyalla
# Processing Record 11 of Set 10 | mount isa
# Processing Record 12 of Set 10 | cherskiy
# Processing Record 13 of Set 10 | tabou
# Processing Record 14 of Set 10 | haapiti
# Processing Record 15 of Set 10 | laela
# Processing Record 16 of Set 10 | cortez
# Processing Record 17 of Set 10 | kiama
# Processing Record 18 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 10 | sao joao da barra
# Processing Record 20 of Set 10 | honiara
# Processing Record 21 of Set 10 | selma
# Processing Record 22 of Set 10 | taylorville
# Processing Record 23 of Set 10 | berlevag
# Processing Record 24 of Set 10 | semey
# Processing Record 25 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 10 | corinto
# Processing Record 27 of Set 10 | hailar
# Processing Record 28 of Set 10 | port blair
# Processing Record 29 of Set 10 | srednekolymsk
# Processing Record 30 of Set 10 | belturbet
# Processing Record 31 of Set 10 | kruisfontein
# Processing Record 32 of Set 10 | vernon
# Processing Record 33 of Set 10 | nome
# Processing Record 34 of Set 10 | tucurui
# Processing Record 35 of Set 10 | svetlogorsk
# Processing Record 36 of Set 10 | groningen
# Processing Record 37 of Set 10 | aracati
# Processing Record 38 of Set 10 | montalban
# Processing Record 39 of Set 10 | kennett
# Processing Record 40 of Set 10 | celina
# Processing Record 41 of Set 10 | alice springs
# Processing Record 42 of Set 10 | abong mbang
# Processing Record 43 of Set 10 | porto walter
# Processing Record 44 of Set 10 | chongqing
# Processing Record 45 of Set 10 | biak
# Processing Record 46 of Set 10 | havre-saint-pierre
# Processing Record 47 of Set 10 | weiser
# Processing Record 48 of Set 10 | sao filipe
# Processing Record 49 of Set 10 | sorland
# Processing Record 50 of Set 10 | awbari
# Processing Record 1 of Set 11 | lavrentiya
# Processing Record 2 of Set 11 | sarankhola
# Processing Record 3 of Set 11 | sinisian
# Processing Record 4 of Set 11 | baie-comeau
# Processing Record 5 of Set 11 | maraa
# Processing Record 6 of Set 11 | konibodom
# Processing Record 7 of Set 11 | walvis bay
# Processing Record 8 of Set 11 | taltal
# Processing Record 9 of Set 11 | port hawkesbury
# Processing Record 10 of Set 11 | kikwit
# Processing Record 11 of Set 11 | birao
# Processing Record 12 of Set 11 | ivankiv
# Processing Record 13 of Set 11 | pravokumskoye
# Processing Record 14 of Set 11 | sudak
# Processing Record 15 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 11 | florence
# Processing Record 17 of Set 11 | envira
# Processing Record 18 of Set 11 | lucapa
# Processing Record 19 of Set 11 | kailua
# Processing Record 20 of Set 11 | sao jose da coroa grande
# Processing Record 21 of Set 11 | kirakira
# Processing Record 22 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 11 | mungwi
# Processing Record 24 of Set 11 | muisne
# Processing Record 25 of Set 11 | marang
# Processing Record 26 of Set 11 | milkovo
# Processing Record 27 of Set 11 | samarai
# Processing Record 28 of Set 11 | severobaykalsk
# Processing Record 29 of Set 11 | frontera
# Processing Record 30 of Set 11 | hervey bay
# Processing Record 31 of Set 11 | baihar
# Processing Record 32 of Set 11 | santa cruz
# Processing Record 33 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 11 | esperance
# Processing Record 35 of Set 11 | swan river
# Processing Record 36 of Set 11 | mayo
# Processing Record 37 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 11 | nola
# Processing Record 39 of Set 11 | baykit
# Processing Record 40 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 11 | maningrida
# Processing Record 42 of Set 11 | galveston
# Processing Record 43 of Set 11 | concarneau
# Processing Record 44 of Set 11 | krasnogorsk
# Processing Record 45 of Set 11 | dauphin
# Processing Record 46 of Set 11 | humaita
# Processing Record 47 of Set 11 | kaspiysk
# Processing Record 48 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 11 | jeremie
# Processing Record 50 of Set 11 | panguna
# Processing Record 1 of Set 12 | dakar
# Processing Record 2 of Set 12 | ust-kulom
# Processing Record 3 of Set 12 | kazanka
# Processing Record 4 of Set 12 | guelengdeng
# City not found. Skipping...
# Processing Record 5 of Set 12 | beian
# Processing Record 6 of Set 12 | tyukalinsk
# Processing Record 7 of Set 12 | komsomolskiy
# Processing Record 8 of Set 12 | richards bay
# Processing Record 9 of Set 12 | paita
# Processing Record 10 of Set 12 | fort-shevchenko
# Processing Record 11 of Set 12 | barcelos
# Processing Record 12 of Set 12 | talah
# City not found. Skipping...
# Processing Record 13 of Set 12 | kalga
# Processing Record 14 of Set 12 | bayanday
# Processing Record 15 of Set 12 | cairns
# Processing Record 16 of Set 12 | san carlos de bariloche
# Processing Record 17 of Set 12 | contamana
# Processing Record 18 of Set 12 | asosa
# Processing Record 19 of Set 12 | iraray
# Processing Record 20 of Set 12 | baoding
# Processing Record 21 of Set 12 | beitbridge
# Processing Record 22 of Set 12 | yinchuan
# Processing Record 23 of Set 12 | russell
# Processing Record 24 of Set 12 | maxixe
# Processing Record 25 of Set 12 | radom
# Processing Record 26 of Set 12 | muros
# Processing Record 27 of Set 12 | lake havasu city
# Processing Record 28 of Set 12 | rogun
# City not found. Skipping...
# Processing Record 29 of Set 12 | katrineholm
# Processing Record 30 of Set 12 | mali
# Processing Record 31 of Set 12 | texarkana
# Processing Record 32 of Set 12 | marsa matruh
# Processing Record 33 of Set 12 | abu samrah
# Processing Record 34 of Set 12 | saint-donat-de-montcalm
# Processing Record 35 of Set 12 | korcula
# Processing Record 36 of Set 12 | kendari
# Processing Record 37 of Set 12 | mocuba
# Processing Record 38 of Set 12 | fayetteville
# Processing Record 39 of Set 12 | merauke
# Processing Record 40 of Set 12 | hovd
# Processing Record 41 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 12 | port keats
# Processing Record 43 of Set 12 | mitsamiouli
# Processing Record 44 of Set 12 | vostochnyy
# Processing Record 45 of Set 12 | maniitsoq
# Processing Record 46 of Set 12 | ahipara
# Processing Record 47 of Set 12 | staryy nadym
# Processing Record 48 of Set 12 | kapoeta
# Processing Record 49 of Set 12 | flin flon
# Processing Record 50 of Set 12 | diamantino
# Processing Record 1 of Set 13 | azare
# Processing Record 2 of Set 13 | rome
# Processing Record 3 of Set 13 | the valley
# Processing Record 4 of Set 13 | samana
# Processing Record 5 of Set 13 | katherine
# Processing Record 6 of Set 13 | coffs harbour
# Processing Record 7 of Set 13 | rabo de peixe
# Processing Record 8 of Set 13 | mokhsogollokh
# Processing Record 9 of Set 13 | qingdao
# Processing Record 10 of Set 13 | winslow
# Processing Record 11 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 13 | harper
# Processing Record 13 of Set 13 | chimore
# Processing Record 14 of Set 13 | ankpa
# Processing Record 15 of Set 13 | dumabato
# Processing Record 16 of Set 13 | mangrol
# Processing Record 17 of Set 13 | mikhaylovka
# Processing Record 18 of Set 13 | mvuma
# Processing Record 19 of Set 13 | sambava
# Processing Record 20 of Set 13 | kashan
# Processing Record 21 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 13 | oran
# Processing Record 24 of Set 13 | boli
# Processing Record 25 of Set 13 | turayf
# Processing Record 26 of Set 13 | conde
# Processing Record 27 of Set 13 | okhotsk
# Processing Record 28 of Set 13 | nanchang
# Processing Record 29 of Set 13 | sadiqabad
# Processing Record 30 of Set 13 | warmbad
# Processing Record 31 of Set 13 | sokolo
# Processing Record 32 of Set 13 | ukrayinka
# Processing Record 33 of Set 13 | jiaocheng
# Processing Record 34 of Set 13 | thinadhoo
# Processing Record 35 of Set 13 | pedernales
# Processing Record 36 of Set 13 | mehamn
# Processing Record 37 of Set 13 | dubti
# Processing Record 38 of Set 13 | tuatapere
# Processing Record 39 of Set 13 | caravelas
# Processing Record 40 of Set 13 | kisangani
# Processing Record 41 of Set 13 | fare
# Processing Record 42 of Set 13 | ranau
# Processing Record 43 of Set 13 | praia da vitoria
# Processing Record 44 of Set 13 | karratha
# Processing Record 45 of Set 13 | fenoarivo atsinanana
# Processing Record 46 of Set 13 | san quintin
# Processing Record 47 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 49 of Set 13 | ca mau
# Processing Record 50 of Set 13 | mahibadhoo
# Processing Record 1 of Set 14 | asyut
# Processing Record 2 of Set 14 | rodeo
# Processing Record 3 of Set 14 | mabaruma
# Processing Record 4 of Set 14 | bilma
# Processing Record 5 of Set 14 | ndele
# Processing Record 6 of Set 14 | lazaro cardenas
# Processing Record 7 of Set 14 | rafraf
# Processing Record 8 of Set 14 | hanyang
# Processing Record 9 of Set 14 | gizo
# Processing Record 10 of Set 14 | tonj
# Processing Record 11 of Set 14 | kununurra
# Processing Record 12 of Set 14 | beira
# Processing Record 13 of Set 14 | cabinda
# Processing Record 14 of Set 14 | lunglei
# Processing Record 15 of Set 14 | hami
# Processing Record 16 of Set 14 | makakilo city
# Processing Record 17 of Set 14 | touros
# Processing Record 18 of Set 14 | gotsu
# Processing Record 19 of Set 14 | bonavista
# Processing Record 20 of Set 14 | wembley
# Processing Record 21 of Set 14 | carutapera
# Processing Record 22 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 14 | boromo
# Processing Record 24 of Set 14 | saint-pierre
# Processing Record 25 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 14 | iquique
# Processing Record 27 of Set 14 | bintulu
# Processing Record 28 of Set 14 | camana
# Processing Record 29 of Set 14 | puerto quijarro
# Processing Record 30 of Set 14 | urkarakh
# Processing Record 31 of Set 14 | tual
# Processing Record 32 of Set 14 | akyab
# Processing Record 33 of Set 14 | kempsey
# Processing Record 34 of Set 14 | guiyang
# Processing Record 35 of Set 14 | phalaborwa
# Processing Record 36 of Set 14 | naryan-mar
# Processing Record 37 of Set 14 | khandyga
# Processing Record 38 of Set 14 | mme
# City not found. Skipping...
# Processing Record 39 of Set 14 | oranjemund
# Processing Record 40 of Set 14 | san vicente
# Processing Record 41 of Set 14 | poltava
# Processing Record 42 of Set 14 | yarmouth
# Processing Record 43 of Set 14 | vajszlo
# Processing Record 44 of Set 14 | yatou
# Processing Record 45 of Set 14 | lahaina
# Processing Record 46 of Set 14 | togur
# Processing Record 47 of Set 14 | labuhan
# Processing Record 48 of Set 14 | nehe
# Processing Record 49 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 50 of Set 14 | orange cove
# Processing Record 1 of Set 15 | sao gabriel da cachoeira
# Processing Record 2 of Set 15 | middelburg
# Processing Record 3 of Set 15 | yizheng
# Processing Record 4 of Set 15 | dong hoi
# Processing Record 5 of Set 15 | mingguang
# Processing Record 6 of Set 15 | gornopravdinsk
# Processing Record 7 of Set 15 | utiel
# Processing Record 8 of Set 15 | ritchie
# Processing Record 9 of Set 15 | avera
# Processing Record 10 of Set 15 | rodrigues alves
# Processing Record 11 of Set 15 | verkhnyaya inta
# Processing Record 12 of Set 15 | duncan
# Processing Record 13 of Set 15 | ust-koksa
# Processing Record 14 of Set 15 | boende
# Processing Record 15 of Set 15 | sabang
# Processing Record 16 of Set 15 | erzin
# Processing Record 17 of Set 15 | nushki
# Processing Record 18 of Set 15 | aktau
# Processing Record 19 of Set 15 | olpe
# Processing Record 20 of Set 15 | sinop
# Processing Record 21 of Set 15 | mykolayiv
# Processing Record 22 of Set 15 | mtimbira
# Processing Record 23 of Set 15 | odienne
# Processing Record 24 of Set 15 | sangar
# Processing Record 25 of Set 15 | farap
# Processing Record 26 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 15 | hosakote
# Processing Record 28 of Set 15 | jakar
# Processing Record 29 of Set 15 | putignano
# Processing Record 30 of Set 15 | brive-la-gaillarde
# Processing Record 31 of Set 15 | santa ines
# Processing Record 32 of Set 15 | dargaville
# Processing Record 33 of Set 15 | barcs
# Processing Record 34 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 15 | luhyny
# Processing Record 36 of Set 15 | fredericksburg
# Processing Record 37 of Set 15 | bella vista
# Processing Record 38 of Set 15 | price
# Processing Record 39 of Set 15 | tucumcari
# Processing Record 40 of Set 15 | tiarei
# Processing Record 41 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 15 | sola
# Processing Record 43 of Set 15 | liberal
# Processing Record 44 of Set 15 | belyy yar
# Processing Record 45 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 46 of Set 15 | verkh-usugli
# Processing Record 47 of Set 15 | itaituba
# Processing Record 48 of Set 15 | mao
# Processing Record 49 of Set 15 | zaysan
# Processing Record 50 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 1 of Set 16 | fraga
# Processing Record 2 of Set 16 | jinchengjiang
# City not found. Skipping...
# Processing Record 3 of Set 16 | ouadda
# Processing Record 4 of Set 16 | chenzhou
# Processing Record 5 of Set 16 | kautokeino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a list in a dictionary then convert it to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     48.99        88         100
# 1      Souillac      MU -20.5167   57.5167     75.20       100          75
# 2       Kavieng      PG  -2.5744  150.7967     78.37        77         100
# 3         Vaini      TO -21.2000 -175.2000     73.40        88          20
# 4     Mahebourg      MU -20.4081   57.7000     75.20       100          75
# 5  Punta Arenas      CL -53.1500  -70.9167     50.00        53          75
# 6       Mataura      NZ -46.1927  168.8643     50.00        95         100
# 7       Rikitea      PF -23.1203 -134.9692     78.57        69           7
# 8        Castro      BR -24.7911  -50.0119     70.75        86          58
# 9     Nantucket      US  41.2835  -70.0995     46.40        87          90
#
#    Wind Speed Current Description
# 0        1.99     overcast clouds
# 1        8.05       moderate rain
# 2       13.29          light rain
# 3        4.61          few clouds
# 4        8.05       moderate rain
# 5       25.32       broken clouds
# 6        3.00          light rain
# 7       10.38           clear sky
# 8        4.74       broken clouds
# 9       12.66                mist

# %%
# Create csv output file (csv)
output_data_file = "weather-database\WeatherPy_Database.csv"

#Export the file
city_data_df.to_csv(output_data_file , index_label='City_ID')
