# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combos
lats = np.random.uniform(-90 , 90 , size = 2000)
lngs = np.random.uniform(-180 , 180 , size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then add to the cities list
    if city not in cities:
        cities.append(city)
        
# Print length of city count to confirm enough
len(cities)
# Out:
# 732

# %%
city_data = []
print("starting to log city_data")
print("-------------------------")

# Create Counters
record_count = 1
set_count = 1

url = "https://api.openweathermap.org/data/2.5/weather?&units=imperial&appid=" + weather_api_key
# loop through the cities list
for i, city in enumerate(cities):
    
    # Group the cities in sets of 50 to log the process as we find the weather data
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        
    # Create endpoint url with each city
    city_url = url + "&q=" + city.replace(" " , "+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# starting to log city_data
# -------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | luderitz
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | tuatapere
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | lagoa
# Processing Record 15 of Set 1 | yulara
# Processing Record 16 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | seydi
# Processing Record 19 of Set 1 | havre-saint-pierre
# Processing Record 20 of Set 1 | mehamn
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | namatanai
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | baillif
# Processing Record 28 of Set 1 | maningrida
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | erdaojiang
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | kachiry
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | te anau
# Processing Record 35 of Set 1 | empangeni
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | buala
# Processing Record 38 of Set 1 | homa bay
# Processing Record 39 of Set 1 | salvador
# Processing Record 40 of Set 1 | puksoozero
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | san pedro de macoris
# Processing Record 44 of Set 1 | kluang
# Processing Record 45 of Set 1 | isangel
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | sechelt
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | nantai
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | ikalamavony
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | mbour
# Processing Record 10 of Set 2 | byron bay
# Processing Record 11 of Set 2 | kaabong
# Processing Record 12 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | pembroke
# Processing Record 15 of Set 2 | shenjiamen
# Processing Record 16 of Set 2 | rawson
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | vestmannaeyjar
# Processing Record 19 of Set 2 | sobolevo
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | nome
# Processing Record 22 of Set 2 | magadan
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | coihaique
# Processing Record 28 of Set 2 | russell
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | kismayo
# Processing Record 31 of Set 2 | huaiyuan
# Processing Record 32 of Set 2 | kon tum
# Processing Record 33 of Set 2 | olavarria
# Processing Record 34 of Set 2 | tahta
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 2 | lasa
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | burnie
# Processing Record 41 of Set 2 | mandera
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | morondava
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | san andres
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | cap malheureux
# Processing Record 49 of Set 2 | aklavik
# Processing Record 50 of Set 2 | barinitas
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | ormara
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | port hardy
# Processing Record 5 of Set 3 | camocim
# Processing Record 6 of Set 3 | dzaoudzi
# Processing Record 7 of Set 3 | usinsk
# Processing Record 8 of Set 3 | half moon bay
# Processing Record 9 of Set 3 | fukue
# Processing Record 10 of Set 3 | barcarena
# Processing Record 11 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 3 | khandyga
# Processing Record 13 of Set 3 | vila velha
# Processing Record 14 of Set 3 | sao filipe
# Processing Record 15 of Set 3 | saint austell
# Processing Record 16 of Set 3 | villa carlos paz
# Processing Record 17 of Set 3 | severo-kurilsk
# Processing Record 18 of Set 3 | san jeronimo
# Processing Record 19 of Set 3 | calvinia
# Processing Record 20 of Set 3 | kijang
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | comodoro rivadavia
# Processing Record 23 of Set 3 | dauphin
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | vila franca do campo
# Processing Record 26 of Set 3 | kaitangata
# Processing Record 27 of Set 3 | bonthe
# Processing Record 28 of Set 3 | ballina
# Processing Record 29 of Set 3 | odda
# Processing Record 30 of Set 3 | buenos aires
# Processing Record 31 of Set 3 | shelburne
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | mosquera
# Processing Record 34 of Set 3 | san patricio
# Processing Record 35 of Set 3 | aksu
# Processing Record 36 of Set 3 | ilulissat
# Processing Record 37 of Set 3 | meulaboh
# Processing Record 38 of Set 3 | inhambane
# Processing Record 39 of Set 3 | qasigiannguit
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | korem
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | cockburn town
# Processing Record 47 of Set 3 | guerrero
# Processing Record 48 of Set 3 | hearst
# Processing Record 49 of Set 3 | atuona
# Processing Record 50 of Set 3 | itarema
# Processing Record 1 of Set 4 | nalut
# Processing Record 2 of Set 4 | road town
# Processing Record 3 of Set 4 | igarka
# Processing Record 4 of Set 4 | kiama
# Processing Record 5 of Set 4 | syracuse
# Processing Record 6 of Set 4 | saveh
# Processing Record 7 of Set 4 | souillac
# Processing Record 8 of Set 4 | saint anthony
# Processing Record 9 of Set 4 | chokurdakh
# Processing Record 10 of Set 4 | rokytnice nad jizerou
# Processing Record 11 of Set 4 | furth im wald
# Processing Record 12 of Set 4 | narsaq
# Processing Record 13 of Set 4 | assare
# Processing Record 14 of Set 4 | gongzhuling
# Processing Record 15 of Set 4 | owando
# Processing Record 16 of Set 4 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | naples
# Processing Record 19 of Set 4 | spring
# Processing Record 20 of Set 4 | boa vista
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | sorland
# Processing Record 23 of Set 4 | esperance
# Processing Record 24 of Set 4 | sao joao da barra
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | nara
# Processing Record 27 of Set 4 | saint george
# Processing Record 28 of Set 4 | bambous virieux
# Processing Record 29 of Set 4 | norman
# Processing Record 30 of Set 4 | ahipara
# Processing Record 31 of Set 4 | umm lajj
# Processing Record 32 of Set 4 | rincon
# Processing Record 33 of Set 4 | sarana
# Processing Record 34 of Set 4 | kavaratti
# Processing Record 35 of Set 4 | hami
# Processing Record 36 of Set 4 | broome
# Processing Record 37 of Set 4 | olafsvik
# Processing Record 38 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 4 | tiksi
# Processing Record 40 of Set 4 | nsanje
# Processing Record 41 of Set 4 | kaspiyskiy
# Processing Record 42 of Set 4 | brumadinho
# Processing Record 43 of Set 4 | mayo
# Processing Record 44 of Set 4 | saint simons
# Processing Record 45 of Set 4 | abonnema
# Processing Record 46 of Set 4 | ribeira grande
# Processing Record 47 of Set 4 | constitucion
# Processing Record 48 of Set 4 | turukhansk
# Processing Record 49 of Set 4 | grindavik
# Processing Record 50 of Set 4 | yen bai
# Processing Record 1 of Set 5 | balabac
# Processing Record 2 of Set 5 | lebu
# Processing Record 3 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 5 | berlevag
# Processing Record 5 of Set 5 | jalingo
# Processing Record 6 of Set 5 | juigalpa
# Processing Record 7 of Set 5 | jacareacanga
# Processing Record 8 of Set 5 | kutum
# Processing Record 9 of Set 5 | labuhan
# Processing Record 10 of Set 5 | maple creek
# Processing Record 11 of Set 5 | antalaha
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | dengzhou
# Processing Record 15 of Set 5 | lebanon
# Processing Record 16 of Set 5 | portland
# Processing Record 17 of Set 5 | griffith
# Processing Record 18 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | kedougou
# Processing Record 21 of Set 5 | acapulco
# Processing Record 22 of Set 5 | kaduy
# Processing Record 23 of Set 5 | hamilton
# Processing Record 24 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 5 | savannah bight
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | mount gambier
# Processing Record 29 of Set 5 | panaba
# Processing Record 30 of Set 5 | dauriya
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | manono
# Processing Record 33 of Set 5 | mahebourg
# Processing Record 34 of Set 5 | noumea
# Processing Record 35 of Set 5 | talnakh
# Processing Record 36 of Set 5 | beringovskiy
# Processing Record 37 of Set 5 | vao
# Processing Record 38 of Set 5 | panguna
# Processing Record 39 of Set 5 | kashan
# Processing Record 40 of Set 5 | balakhninskiy
# Processing Record 41 of Set 5 | bathsheba
# Processing Record 42 of Set 5 | cherskiy
# Processing Record 43 of Set 5 | riviere-au-renard
# Processing Record 44 of Set 5 | umm kaddadah
# Processing Record 45 of Set 5 | saint-augustin
# Processing Record 46 of Set 5 | kuraymah
# Processing Record 47 of Set 5 | caravelas
# Processing Record 48 of Set 5 | santa cruz
# Processing Record 49 of Set 5 | nelson bay
# Processing Record 50 of Set 5 | tasiilaq
# Processing Record 1 of Set 6 | sretensk
# Processing Record 2 of Set 6 | karatau
# Processing Record 3 of Set 6 | arman
# Processing Record 4 of Set 6 | virden
# Processing Record 5 of Set 6 | batagay
# Processing Record 6 of Set 6 | ponta delgada
# Processing Record 7 of Set 6 | teacapan
# Processing Record 8 of Set 6 | bengkulu
# Processing Record 9 of Set 6 | chuzhou
# Processing Record 10 of Set 6 | the valley
# Processing Record 11 of Set 6 | bela cruz
# Processing Record 12 of Set 6 | mayya
# Processing Record 13 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 6 | klaksvik
# Processing Record 15 of Set 6 | grand gaube
# Processing Record 16 of Set 6 | rio gallegos
# Processing Record 17 of Set 6 | geraldton
# Processing Record 18 of Set 6 | tambopata
# Processing Record 19 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 6 | adet
# Processing Record 21 of Set 6 | xining
# Processing Record 22 of Set 6 | scarborough
# Processing Record 23 of Set 6 | port blair
# Processing Record 24 of Set 6 | rio grande
# Processing Record 25 of Set 6 | pineville
# Processing Record 26 of Set 6 | georgetown
# Processing Record 27 of Set 6 | muisne
# Processing Record 28 of Set 6 | peleduy
# Processing Record 29 of Set 6 | sokoni
# Processing Record 30 of Set 6 | hailar
# Processing Record 31 of Set 6 | nantucket
# Processing Record 32 of Set 6 | makakilo city
# Processing Record 33 of Set 6 | sungaipenuh
# Processing Record 34 of Set 6 | iralaya
# Processing Record 35 of Set 6 | khani
# Processing Record 36 of Set 6 | dana point
# Processing Record 37 of Set 6 | stonewall
# Processing Record 38 of Set 6 | dhidhdhoo
# Processing Record 39 of Set 6 | mogadishu
# Processing Record 40 of Set 6 | saldanha
# Processing Record 41 of Set 6 | lodwar
# Processing Record 42 of Set 6 | kyzyl
# Processing Record 43 of Set 6 | luau
# Processing Record 44 of Set 6 | wanning
# Processing Record 45 of Set 6 | nanortalik
# Processing Record 46 of Set 6 | luchegorsk
# Processing Record 47 of Set 6 | ketchikan
# Processing Record 48 of Set 6 | esmeraldas
# Processing Record 49 of Set 6 | mandalgovi
# Processing Record 50 of Set 6 | kungurtug
# Processing Record 1 of Set 7 | rundu
# Processing Record 2 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 3 of Set 7 | rio de janeiro
# Processing Record 4 of Set 7 | eydhafushi
# Processing Record 5 of Set 7 | faanui
# Processing Record 6 of Set 7 | victoria
# Processing Record 7 of Set 7 | indio
# Processing Record 8 of Set 7 | ahuimanu
# Processing Record 9 of Set 7 | santa fe
# Processing Record 10 of Set 7 | natal
# Processing Record 11 of Set 7 | pangnirtung
# Processing Record 12 of Set 7 | eureka
# Processing Record 13 of Set 7 | minuri
# Processing Record 14 of Set 7 | tucuma
# Processing Record 15 of Set 7 | sakaiminato
# Processing Record 16 of Set 7 | great falls
# Processing Record 17 of Set 7 | savino
# Processing Record 18 of Set 7 | agirish
# Processing Record 19 of Set 7 | kargasok
# Processing Record 20 of Set 7 | mahibadhoo
# Processing Record 21 of Set 7 | kariba
# Processing Record 22 of Set 7 | rydultowy
# Processing Record 23 of Set 7 | osorno
# Processing Record 24 of Set 7 | bandarbeyla
# Processing Record 25 of Set 7 | awjilah
# Processing Record 26 of Set 7 | norman wells
# Processing Record 27 of Set 7 | baturaja
# Processing Record 28 of Set 7 | nenjiang
# Processing Record 29 of Set 7 | attock
# Processing Record 30 of Set 7 | surt
# Processing Record 31 of Set 7 | shetpe
# Processing Record 32 of Set 7 | shibganj
# Processing Record 33 of Set 7 | saurimo
# Processing Record 34 of Set 7 | shitanjing
# Processing Record 35 of Set 7 | flinders
# Processing Record 36 of Set 7 | lumphat
# Processing Record 37 of Set 7 | mackay
# Processing Record 38 of Set 7 | riyadh
# Processing Record 39 of Set 7 | oranjemund
# Processing Record 40 of Set 7 | vyartsilya
# Processing Record 41 of Set 7 | siloam springs
# Processing Record 42 of Set 7 | marsa matruh
# Processing Record 43 of Set 7 | toktogul
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | sagarejo
# Processing Record 46 of Set 7 | mareeba
# Processing Record 47 of Set 7 | rancho palos verdes
# Processing Record 48 of Set 7 | buchanan
# Processing Record 49 of Set 7 | zurrieq
# Processing Record 50 of Set 7 | avera
# Processing Record 1 of Set 8 | valparaiso
# Processing Record 2 of Set 8 | altay
# Processing Record 3 of Set 8 | gornopravdinsk
# Processing Record 4 of Set 8 | tilichiki
# Processing Record 5 of Set 8 | apache junction
# Processing Record 6 of Set 8 | axim
# Processing Record 7 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 8 | novikovo
# Processing Record 9 of Set 8 | nemuro
# Processing Record 10 of Set 8 | ankpa
# Processing Record 11 of Set 8 | srednekolymsk
# Processing Record 12 of Set 8 | yangambi
# Processing Record 13 of Set 8 | fare
# Processing Record 14 of Set 8 | pandamatenga
# Processing Record 15 of Set 8 | tuy hoa
# Processing Record 16 of Set 8 | yanam
# Processing Record 17 of Set 8 | sao raimundo nonato
# Processing Record 18 of Set 8 | inverell
# Processing Record 19 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 8 | sola
# Processing Record 21 of Set 8 | neuquen
# Processing Record 22 of Set 8 | ibra
# Processing Record 23 of Set 8 | kupang
# Processing Record 24 of Set 8 | qaqortoq
# Processing Record 25 of Set 8 | ambulu
# Processing Record 26 of Set 8 | xuanhua
# Processing Record 27 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 8 | davila
# Processing Record 29 of Set 8 | iquique
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | vagur
# Processing Record 32 of Set 8 | osoyoos
# Processing Record 33 of Set 8 | hambantota
# Processing Record 34 of Set 8 | fushan
# Processing Record 35 of Set 8 | camargo
# Processing Record 36 of Set 8 | miyako
# Processing Record 37 of Set 8 | oktyabrskoye
# Processing Record 38 of Set 8 | kulhudhuffushi
# Processing Record 39 of Set 8 | rennes
# Processing Record 40 of Set 8 | villarrobledo
# Processing Record 41 of Set 8 | svetlaya
# Processing Record 42 of Set 8 | marzuq
# Processing Record 43 of Set 8 | moron
# Processing Record 44 of Set 8 | hovd
# Processing Record 45 of Set 8 | kalmunai
# Processing Record 46 of Set 8 | opuwo
# Processing Record 47 of Set 8 | atambua
# Processing Record 48 of Set 8 | poyarkovo
# Processing Record 49 of Set 8 | rognan
# Processing Record 50 of Set 8 | gallup
# Processing Record 1 of Set 9 | cristobal obregon
# Processing Record 2 of Set 9 | huarmey
# Processing Record 3 of Set 9 | gornoye loo
# Processing Record 4 of Set 9 | san quintin
# Processing Record 5 of Set 9 | karagay
# Processing Record 6 of Set 9 | de aar
# Processing Record 7 of Set 9 | solnechnyy
# Processing Record 8 of Set 9 | birao
# Processing Record 9 of Set 9 | huanan
# Processing Record 10 of Set 9 | chimore
# Processing Record 11 of Set 9 | songjianghe
# Processing Record 12 of Set 9 | novopokrovka
# Processing Record 13 of Set 9 | nago
# Processing Record 14 of Set 9 | udachnyy
# Processing Record 15 of Set 9 | rawa mazowiecka
# Processing Record 16 of Set 9 | berbera
# Processing Record 17 of Set 9 | northam
# Processing Record 18 of Set 9 | magole
# Processing Record 19 of Set 9 | alot
# Processing Record 20 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 9 | luorong
# Processing Record 22 of Set 9 | chaadayevka
# Processing Record 23 of Set 9 | naliya
# Processing Record 24 of Set 9 | henties bay
# Processing Record 25 of Set 9 | godec
# City not found. Skipping...
# Processing Record 26 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 27 of Set 9 | eyl
# Processing Record 28 of Set 9 | taltal
# Processing Record 29 of Set 9 | matina
# Processing Record 30 of Set 9 | hayden
# Processing Record 31 of Set 9 | whitianga
# Processing Record 32 of Set 9 | svetlogorsk
# Processing Record 33 of Set 9 | lamu
# Processing Record 34 of Set 9 | sabang
# Processing Record 35 of Set 9 | poum
# Processing Record 36 of Set 9 | harper
# Processing Record 37 of Set 9 | mitsamiouli
# Processing Record 38 of Set 9 | el estor
# Processing Record 39 of Set 9 | casselman
# Processing Record 40 of Set 9 | san carlos
# Processing Record 41 of Set 9 | khakhea
# Processing Record 42 of Set 9 | nuuk
# Processing Record 43 of Set 9 | sambava
# Processing Record 44 of Set 9 | los llanos de aridane
# Processing Record 45 of Set 9 | sinnamary
# Processing Record 46 of Set 9 | clarence town
# Processing Record 47 of Set 9 | santo antonio de padua
# Processing Record 48 of Set 9 | teahupoo
# Processing Record 49 of Set 9 | novyy nekouz
# Processing Record 50 of Set 9 | tecpan
# Processing Record 1 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 10 | bud
# Processing Record 3 of Set 10 | ambanja
# Processing Record 4 of Set 10 | olinda
# Processing Record 5 of Set 10 | hofn
# Processing Record 6 of Set 10 | manicore
# Processing Record 7 of Set 10 | ancud
# Processing Record 8 of Set 10 | beyneu
# Processing Record 9 of Set 10 | coquimbo
# Processing Record 10 of Set 10 | atar
# Processing Record 11 of Set 10 | tadine
# Processing Record 12 of Set 10 | fort nelson
# Processing Record 13 of Set 10 | haines junction
# Processing Record 14 of Set 10 | adre
# Processing Record 15 of Set 10 | buluang
# Processing Record 16 of Set 10 | taoudenni
# Processing Record 17 of Set 10 | chuguyevka
# Processing Record 18 of Set 10 | acarau
# Processing Record 19 of Set 10 | birjand
# Processing Record 20 of Set 10 | porosozero
# Processing Record 21 of Set 10 | necochea
# Processing Record 22 of Set 10 | kidal
# Processing Record 23 of Set 10 | sungai kolok
# City not found. Skipping...
# Processing Record 24 of Set 10 | swan hill
# Processing Record 25 of Set 10 | isla vista
# Processing Record 26 of Set 10 | braniewo
# Processing Record 27 of Set 10 | shouguang
# Processing Record 28 of Set 10 | gulariya
# Processing Record 29 of Set 10 | san carlos de bariloche
# Processing Record 30 of Set 10 | karpogory
# Processing Record 31 of Set 10 | chiriqui grande
# Processing Record 32 of Set 10 | roebourne
# Processing Record 33 of Set 10 | oxbow
# Processing Record 34 of Set 10 | key west
# Processing Record 35 of Set 10 | bandung
# Processing Record 36 of Set 10 | vanavara
# Processing Record 37 of Set 10 | sao lourenco da serra
# Processing Record 38 of Set 10 | kahului
# Processing Record 39 of Set 10 | padang
# Processing Record 40 of Set 10 | bhuban
# Processing Record 41 of Set 10 | seoul
# Processing Record 42 of Set 10 | baghdad
# Processing Record 43 of Set 10 | pop
# Processing Record 44 of Set 10 | gamba
# Processing Record 45 of Set 10 | takab
# Processing Record 46 of Set 10 | puerto carreno
# Processing Record 47 of Set 10 | yar-sale
# Processing Record 48 of Set 10 | samfya
# Processing Record 49 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 50 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 11 | mangrol
# Processing Record 2 of Set 11 | kruisfontein
# Processing Record 3 of Set 11 | juneau
# Processing Record 4 of Set 11 | clyde river
# Processing Record 5 of Set 11 | wukari
# Processing Record 6 of Set 11 | grasse
# Processing Record 7 of Set 11 | sherlovaya gora
# Processing Record 8 of Set 11 | morada nova
# Processing Record 9 of Set 11 | wuwei
# Processing Record 10 of Set 11 | kells
# Processing Record 11 of Set 11 | saint-francois
# Processing Record 12 of Set 11 | bahia blanca
# Processing Record 13 of Set 11 | jiuquan
# Processing Record 14 of Set 11 | luwuk
# Processing Record 15 of Set 11 | tsabong
# Processing Record 16 of Set 11 | yerbogachen
# Processing Record 17 of Set 11 | rabo de peixe
# Processing Record 18 of Set 11 | fortuna
# Processing Record 19 of Set 11 | dawei
# Processing Record 20 of Set 11 | abu dhabi
# Processing Record 21 of Set 11 | lompoc
# Processing Record 22 of Set 11 | girua
# Processing Record 23 of Set 11 | ternate
# Processing Record 24 of Set 11 | puerto baquerizo moreno
# Processing Record 25 of Set 11 | parrita
# Processing Record 26 of Set 11 | alofi
# Processing Record 27 of Set 11 | bucerias
# Processing Record 28 of Set 11 | san rafael
# Processing Record 29 of Set 11 | dingle
# Processing Record 30 of Set 11 | sayyan
# Processing Record 31 of Set 11 | vardo
# Processing Record 32 of Set 11 | marsabit
# Processing Record 33 of Set 11 | kurilsk
# Processing Record 34 of Set 11 | muros
# Processing Record 35 of Set 11 | ngunguru
# Processing Record 36 of Set 11 | saint-pierre
# Processing Record 37 of Set 11 | auki
# Processing Record 38 of Set 11 | anori
# Processing Record 39 of Set 11 | erzin
# Processing Record 40 of Set 11 | durban
# Processing Record 41 of Set 11 | chapais
# Processing Record 42 of Set 11 | arrecife
# Processing Record 43 of Set 11 | leh
# Processing Record 44 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | lerwick
# Processing Record 46 of Set 11 | petrovsk
# Processing Record 47 of Set 11 | zhigansk
# Processing Record 48 of Set 11 | bilibino
# Processing Record 49 of Set 11 | iquitos
# Processing Record 50 of Set 11 | oranjestad
# Processing Record 1 of Set 12 | araouane
# Processing Record 2 of Set 12 | koslan
# Processing Record 3 of Set 12 | stephenville
# Processing Record 4 of Set 12 | teknaf
# Processing Record 5 of Set 12 | lima
# Processing Record 6 of Set 12 | novo aripuana
# Processing Record 7 of Set 12 | guerrero negro
# Processing Record 8 of Set 12 | san juan del sur
# Processing Record 9 of Set 12 | mae ramat
# Processing Record 10 of Set 12 | chaochou
# City not found. Skipping...
# Processing Record 11 of Set 12 | alice springs
# Processing Record 12 of Set 12 | along
# Processing Record 13 of Set 12 | kununurra
# Processing Record 14 of Set 12 | jimma
# Processing Record 15 of Set 12 | turan
# Processing Record 16 of Set 12 | gobabis
# Processing Record 17 of Set 12 | bitlis
# Processing Record 18 of Set 12 | angra
# City not found. Skipping...
# Processing Record 19 of Set 12 | muscat
# Processing Record 20 of Set 12 | mount isa
# Processing Record 21 of Set 12 | petawawa
# Processing Record 22 of Set 12 | lusambo
# Processing Record 23 of Set 12 | sirjan
# Processing Record 24 of Set 12 | menongue
# Processing Record 25 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 12 | melfi
# Processing Record 27 of Set 12 | mapanas
# Processing Record 28 of Set 12 | kirakira
# Processing Record 29 of Set 12 | pilar
# Processing Record 30 of Set 12 | buraydah
# Processing Record 31 of Set 12 | strezhevoy
# Processing Record 32 of Set 12 | clonakilty
# Processing Record 33 of Set 12 | pacific grove
# Processing Record 34 of Set 12 | kananga
# Processing Record 35 of Set 12 | husavik
# Processing Record 36 of Set 12 | sarangani
# Processing Record 37 of Set 12 | jibuti
# Processing Record 38 of Set 12 | medicine hat
# Processing Record 39 of Set 12 | sarkand
# Processing Record 40 of Set 12 | shingu
# Processing Record 41 of Set 12 | novoagansk
# Processing Record 42 of Set 12 | agadez
# Processing Record 43 of Set 12 | canhotinho
# Processing Record 44 of Set 12 | oussouye
# Processing Record 45 of Set 12 | palm beach
# Processing Record 46 of Set 12 | charters towers
# Processing Record 47 of Set 12 | santa rosa
# Processing Record 48 of Set 12 | pisco
# Processing Record 49 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 12 | puqi
# Processing Record 1 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 13 | vikulovo
# Processing Record 3 of Set 13 | tevaitoa
# Processing Record 4 of Set 13 | fairbanks
# Processing Record 5 of Set 13 | arlit
# Processing Record 6 of Set 13 | pakxan
# Processing Record 7 of Set 13 | ayagoz
# Processing Record 8 of Set 13 | kuah
# Processing Record 9 of Set 13 | nakhon phanom
# Processing Record 10 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 13 | raudeberg
# Processing Record 12 of Set 13 | okoneshnikovo
# Processing Record 13 of Set 13 | emba
# Processing Record 14 of Set 13 | tautira
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | quesnel
# Processing Record 17 of Set 13 | saint andrews
# Processing Record 18 of Set 13 | deputatskiy
# Processing Record 19 of Set 13 | aksarka
# Processing Record 20 of Set 13 | ploufragan
# Processing Record 21 of Set 13 | manavalakurichi
# Processing Record 22 of Set 13 | zapolyarnyy
# Processing Record 23 of Set 13 | pocosol
# Processing Record 24 of Set 13 | heihe
# Processing Record 25 of Set 13 | ornskoldsvik
# Processing Record 26 of Set 13 | galanta
# Processing Record 27 of Set 13 | groton
# Processing Record 28 of Set 13 | san cristobal
# Processing Record 29 of Set 13 | dali
# Processing Record 30 of Set 13 | sarakhs
# Processing Record 31 of Set 13 | bida
# Processing Record 32 of Set 13 | saint-georges
# Processing Record 33 of Set 13 | cabo rojo
# Processing Record 34 of Set 13 | shillong
# Processing Record 35 of Set 13 | rio grande city
# Processing Record 36 of Set 13 | vostok
# Processing Record 37 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 13 | siverskiy
# Processing Record 39 of Set 13 | payo
# Processing Record 40 of Set 13 | dubbo
# Processing Record 41 of Set 13 | puerto escondido
# Processing Record 42 of Set 13 | ustka
# Processing Record 43 of Set 13 | kiunga
# Processing Record 44 of Set 13 | krasnoselkup
# Processing Record 45 of Set 13 | puerto leguizamo
# Processing Record 46 of Set 13 | montevideo
# Processing Record 47 of Set 13 | launceston
# Processing Record 48 of Set 13 | merauke
# Processing Record 49 of Set 13 | jizan
# Processing Record 50 of Set 13 | khromtau
# Processing Record 1 of Set 14 | sovetskaya gavan
# Processing Record 2 of Set 14 | omboue
# Processing Record 3 of Set 14 | barranca
# Processing Record 4 of Set 14 | kiboga
# Processing Record 5 of Set 14 | safwah
# City not found. Skipping...
# Processing Record 6 of Set 14 | kamenka
# Processing Record 7 of Set 14 | key largo
# Processing Record 8 of Set 14 | dunda
# Processing Record 9 of Set 14 | kushima
# Processing Record 10 of Set 14 | leningradskiy
# Processing Record 11 of Set 14 | camden
# Processing Record 12 of Set 14 | laguna
# Processing Record 13 of Set 14 | angoche
# Processing Record 14 of Set 14 | raga
# Processing Record 15 of Set 14 | tura
# Processing Record 16 of Set 14 | llangefni
# Processing Record 17 of Set 14 | college
# Processing Record 18 of Set 14 | cervo
# Processing Record 19 of Set 14 | delvada
# Processing Record 20 of Set 14 | manggar
# Processing Record 21 of Set 14 | carbonia
# Processing Record 22 of Set 14 | taian
# Processing Record 23 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 24 of Set 14 | hualmay
# Processing Record 25 of Set 14 | mizdah
# Processing Record 26 of Set 14 | perigueux
# Processing Record 27 of Set 14 | rybinsk
# Processing Record 28 of Set 14 | lumeje
# Processing Record 29 of Set 14 | ziro
# Processing Record 30 of Set 14 | tucurui
# Processing Record 31 of Set 14 | hay river
# Processing Record 32 of Set 14 | verkhnevilyuysk
# Processing Record 33 of Set 14 | dumas
# Processing Record 34 of Set 14 | garden city
# Processing Record 35 of Set 14 | sur
# Processing Record 36 of Set 14 | pangai
# Processing Record 37 of Set 14 | nioro
# Processing Record 38 of Set 14 | biskamzha
# Processing Record 39 of Set 14 | portmore
# Processing Record 40 of Set 14 | ukiah
# Processing Record 41 of Set 14 | tolaga bay
# Processing Record 42 of Set 14 | todos santos
# Processing Record 43 of Set 14 | amudat
# Processing Record 44 of Set 14 | mahon
# Processing Record 45 of Set 14 | balsas
# Processing Record 46 of Set 14 | ilebo
# Processing Record 47 of Set 14 | canandaigua
# Processing Record 48 of Set 14 | namtsy
# Processing Record 49 of Set 14 | susanville
# Processing Record 50 of Set 14 | mersing
# Processing Record 1 of Set 15 | rahimatpur
# Processing Record 2 of Set 15 | saqqez
# Processing Record 3 of Set 15 | dergachi
# Processing Record 4 of Set 15 | natitingou
# Processing Record 5 of Set 15 | khlevnoye
# Processing Record 6 of Set 15 | diamantino
# Processing Record 7 of Set 15 | gubkinskiy
# Processing Record 8 of Set 15 | ostrovnoy
# Processing Record 9 of Set 15 | vitim
# Processing Record 10 of Set 15 | ilam
# Processing Record 11 of Set 15 | vitoria do mearim
# Processing Record 12 of Set 15 | rokytne
# Processing Record 13 of Set 15 | port lincoln
# Processing Record 14 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 15 | finschhafen
# Processing Record 16 of Set 15 | tela
# Processing Record 17 of Set 15 | staryy nadym
# Processing Record 18 of Set 15 | waipawa
# Processing Record 19 of Set 15 | faya
# Processing Record 20 of Set 15 | vallenar
# Processing Record 21 of Set 15 | adamovka
# Processing Record 22 of Set 15 | kourou
# Processing Record 23 of Set 15 | samarai
# Processing Record 24 of Set 15 | catamarca
# Processing Record 25 of Set 15 | calvia
# Processing Record 26 of Set 15 | chirongui
# Processing Record 27 of Set 15 | ndjole
# Processing Record 28 of Set 15 | lhokseumawe
# Processing Record 29 of Set 15 | leirvik
# Processing Record 30 of Set 15 | maldonado
# Processing Record 31 of Set 15 | palmer
# Processing Record 32 of Set 15 | batticaloa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a list in a dictionary then convert it to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.6001  -73.9662     46.99        42          13
# 1     Luderitz      NA -26.6481   15.1594     80.20        52           6
# 2       Hobart      AU -42.8794  147.3294     55.99        76           0
# 3  Port Alfred      ZA -33.5906   26.8910     66.88        78         100
# 4    Tuatapere      NZ -46.1333  167.6833     53.01        63           6
# 5        Bluff      NZ -46.6000  168.3333     53.01        63          69
# 6  Provideniya      RU  64.3833 -173.3000      0.14        93         100
# 7        Vaini      TO -21.2000 -175.2000     62.60       100          20
# 8      Ushuaia      AR -54.8000  -68.3000     41.00        70          75
# 9       Torbay      CA  47.6666  -52.7314     42.01       100          90
#
#    Wind Speed Current Description
# 0        4.00          few clouds
# 1       29.12           clear sky
# 2        4.61           clear sky
# 3       11.77     overcast clouds
# 4        7.00           clear sky
# 5        7.00       broken clouds
# 6        6.69     overcast clouds
# 7        1.14          few clouds
# 8        5.75       broken clouds
# 9       12.66                 fog

# %%
# Create csv output file (csv)
output_data_file = "weather-database\WeatherPy_Database.csv"

#Export the file
city_data_df.to_csv(output_data_file , index_label='City_ID')
